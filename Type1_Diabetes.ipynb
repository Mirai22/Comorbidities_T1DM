# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dn = pd.read_csv("/Users/macbook/Downloads/glc_insulin_dischargenotes_df.csv")
d_icd = pd.read_csv("/Users/macbook/Downloads/DIAGNOSES_ICD.csv")
d_icd_d = pd.read_csv("/Users/macbook/Downloads/D_ICD_DIAGNOSES.csv")

# %%
dn[dn['SUBJECT_ID'] == 11861]['TEXT'].values[0]
# Out:
# 'Admission Date:  [**2132-8-4**]              Discharge Date:   [**2132-8-6**]\n\nDate of Birth:  [**2105-5-5**]             Sex:   F\n\nService: MEDICINE\n\nAllergies:\nMorphine / Prochlorperazine / Tramadol\n\nAttending:[**First Name3 (LF) 3705**]\nChief Complaint:\nUGIB\n\nMajor Surgical or Invasive Procedure:\nNone\n\nHistory of Present Illness:\n27 year old female PMHx T1DM, gastroperesis, grade1 varices on\nrecent EGD [**1-/2132**], chronic LBP [**1-2**] MVC in [**2129**], and recent\nadmission for DKA that was complicated by a right-sided\npneumothorax presenting with an acute non-traumatic worsening of\nlower back pain. In addition, the patient complains of nausea\nand vomiting x10 today. No clinical features to suggest acute\nabd process including aortic dissection or infectious processes\nincluding epidural abscess or acute spinal cord impingement.\nReassuring that this is per the pt identical to prior\nexacerbations.\nThere are no features on exam to suggest respiratory di
# ...

# %%
dn[dn['SUBJECT_ID'] == 42728]
# Out:
#         Unnamed: 0  SUBJECT_ID  HADM_ID  ICUSTAY_ID  LOS_ICU_days  \
# 653160      653160       42728   142693      299979             1
# 653161      653161       42728   142693      299979             1
# 653162      653162       42728   142693      299979             1
# 653163      653163       42728   142693      299979             1
# 653164      653164       42728   142693      299979             1
# 653165      653165       42728   142693      299979             1
# 653166      653166       42728   142693      299979             1
# 653167      653167       42728   142693      299979             1
#
#         first_ICU_stay            GLCPERIOD    GLC             GLCTIMER  \
# 653160            True  2127-12-05 03:37:00  146.0  2127-12-05 03:37:00
# 653161            True  2127-12-05 22:00:00  169.0  2127-12-05 22:00:00
# 653162            True  2127-12-06 00:00:00    NaN  2127-12-06 00:00:00
# 653163            True  2127-12-06 02:25:00  129.0  2127-12-06 02:25:00
# ...

# %%
d_icd.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
#Für später, wenn man alle T1D gefunden hat
mask = d_icd["SUBJECT_ID"].isin(ID_T1DM)
print(mask)

df_NEU = d_icd[mask]

d_icd_neu1 = df_NEU.sort_values("SUBJECT_ID") 
d_icd_neu1.drop_duplicates(subset=['SUBJECT_ID'],inplace = True)
d_icd_neu1.reset_index(inplace=True)
df_neu1

# %%
d_icd_d.head()
# Out:
#    ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0     174     01166     TB pneumonia-oth test
# 1     175     01170    TB pneumothorax-unspec
# 2     176     01171   TB pneumothorax-no exam
# 3     177     01172  TB pneumothorx-exam unkn
# 4     178     01173  TB pneumothorax-micro dx
#
#                                           LONG_TITLE
# 0  Tuberculous pneumonia [any form], tubercle bac...
# 1              Tuberculous pneumothorax, unspecified
# 2  Tuberculous pneumothorax, bacteriological or h...
# 3  Tuberculous pneumothorax, bacteriological or h...
# 4  Tuberculous pneumothorax, tubercle bacilli fou...

# %%
d_icd_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14567 entries, 0 to 14566
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ROW_ID       14567 non-null  int64
#  1   ICD9_CODE    14567 non-null  object
#  2   SHORT_TITLE  14567 non-null  object
#  3   LONG_TITLE   14567 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 455.3+ KB

# %%
ICD_9_D = [25001, 25003, 25011, 25013, 25021, 25023, 25031, 25033, 25041, 25043, 25051, 25053, 25061, 25063, 25071, 25073, 25081, 25083, 25091, 25093]

# %%
ICD_9_D
# Out:
# [25001,
#  25003,
#  25011,
#  25013,
#  25021,
#  25023,
#  25031,
#  25033,
#  25041,
#  25043,
#  25051,
#  25053,
#  25061,
#  25063,
#  25071,
#  25073,
#  25081,
#  25083,
#  25091,
#  25093]

# %%
d_typ1 = d_icd_d['ICD9_CODE'].isin(ICD_9_D)

# %%
print(d_typ1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14562    False
# 14563    False
# 14564    False
# 14565    False
# 14566    False
# Name: ICD9_CODE, Length: 14567, dtype: bool

# %%
d_typ1 = pd.DataFrame(d_typ1)

# %%
d_typ1
# Out:
#        ICD9_CODE
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 14562      False
# 14563      False
# 14564      False
# 14565      False
# 14566      False
#
# [14567 rows x 1 columns]

# %%
d_typ1_true = d_typ1[d_typ1['ICD9_CODE'] == True]

# %%
d_typ1_true
# Out:
# Empty DataFrame
# Columns: [ICD9_CODE]
# Index: []
